# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
#!dw configure

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import datadotworld as dw

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "drive/My Drive/Colab Notebooks/DW_Matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/DW_Matrix

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_part1/  README.md

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.7/dist-packages/datadotworld/util.py:173: DtypeWarning: Columns (39,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   else func(*args))
# (19387, 48)

# %%
df_usd = df[df.prices_currency == 'USD'].copy()

# %%
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(float)

# %%
df_usd['prices_amountmin'].hist(bins=100)

# %%
filter_max = np.percentile(df_usd['prices_amountmin'], 99)

# %%
np.percentile(df_usd['prices_amountmin'], 99)
# Out:
# 895.0

# %%
df_usd_filter = df_usd [df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter['prices_amountmin'].hist()

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_part1/  README.md

# %%
df.to_csv('data/shoes_prices.csv', index = False)

# %%
# !git add mate
