# %%
print(Hello, Github!)
# Out:
#   File "<ipython-input-1-c45d7c46d757>", line 1
#     print(Hello, Github!)
#                        ^
# SyntaxError: invalid syntax

# %%
print("Hello, Github!")
# Out:
# Hello, Github!
